# %% [markdown]
# ## Tutorial 3b - Transfer Learning

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# Typically we do not train an entire Convolutional Neural Networks from scratch. One reason is that it is rare to have access to enough data to train the networks sufficiently. The other reason, as we have seen in labs 2 and 3, training neural networks can take a long time even on small 32 x 32 pixel images. Extending this to larger images such as the 3 x 224 x 224 that are commonly found in the ImageNet dataset could take weeks on a single GPUs.
#
# Instead, we can use pretrained networks such as the AlexNet, or VGG as feature extractors and train a smaller fully connected ANN to do our final classifications.

# %% [markdown]
# ## AlexNet in PyTorch
#
# Convolutional networks are very commonly used, meaning that there are often alternatives to
# training convolutional networks from scratch. In particular, researchers often release both
# the architecture and **the weights** of the networks they train.
#
# As an example, let's look at the AlexNet model, whose trained weights are included in `torchvision`.
# AlexNet was trained to classify images into one of many categories.
# The AlexNet can be imported and used as shown below.

# %%
# alexnet
import torchvision.models

alexNet = torchvision.models.alexnet(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
alexNet
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Notice that the AlexNet model is split into two parts. There is a component that computes
# "features" using convolutions.

# %%
alexNet.features
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#   (1): ReLU(inplace=True)
#   (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (4): ReLU(inplace=True)
#   (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(inplace=True)
#   (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU(inplace=True)
#   (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %% [markdown]
# There is also a component that classifies the image based on the computed features.

# %%
alexNet.classifier
# Out:
# Sequential(
#   (0): Dropout(p=0.5, inplace=False)
#   (1): Linear(in_features=9216, out_features=4096, bias=True)
#   (2): ReLU(inplace=True)
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=4096, out_features=4096, bias=True)
#   (5): ReLU(inplace=True)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %% [markdown]
# ### AlexNet Features
#
# The first network can be used independently of the second. Specifically, it can be used
# to compute a set of **features** that can be used later on. This idea of using neural
# network activation *features* to represent images is an extremely important one, so it
# is important to understand the idea now.
#
# To see how we can do this, let's first load an image.

# %%
import matplotlib.pyplot as plt
import numpy as np

#laod colour image
img = plt.imread('https://drive.google.com/uc?export=view&id=1oaLVR2hr1_qzpKQ47i9rVUIklwbDcews')
#img = plt.imread('https://upload.wikimedia.org/wikipedia/commons/thumb/1/19/Cat_Director_of_Takagi_village_Muku_Hatojo_Memorial_Library_%283%29.png/800px-Cat_Director_of_Takagi_village_Muku_Hatojo_Memorial_Library_%283%29.png')

img = img[:,:,:3]
plt.imshow(img)

# %% [markdown]
# To use this image we need to convert it into a PyTorch tensor of the appropriate shape.

# %%
import torch

#convert to tensor
x = torch.from_numpy(img) # turn img into a PyTorch tensor
print(x.shape)

x = x.permute(2,0,1)      # move the channel dimension to the beginning
print(x.shape)
# Out:
# torch.Size([350, 210, 3])
# torch.Size([3, 350, 210])

# %% [markdown]
# Next, we feed the image x as an input to our alexNet feature network.

# %%
import torch

#features = alexNet.features(x)
#features.shape

# %% [markdown]
# **This results in an error!** Even when our batch size is 1, we still need the batch size dimension to be set to 1, so that the input
# follows the "NCHW" format (N = batch size, C = channels, H = height, W = width)

# %%
x = x.reshape([1, 3, 350, 210]) # add a dimension for batching
print(x.shape)
# Out:
# torch.Size([1, 3, 350, 210])

# %%
import torch

features = alexNet.features(x)
features.shape
# Out:
# torch.Size([1, 256, 9, 5])

# %% [markdown]
# The set of numbers in `features` is another way of representing our image `x`. Recall that
# our initial image `x` was also represented as a tensor, also a set of numbers representing
# pixel intensity. Geometrically speaking, we are using points in a high-dimensional space to
# represent the images. in our pixel representation, the axes in this high-dimensional space
# were different pixels. In our `features` representation, the axes are not as easily
# interpretable.
#
# But we will want to work with the `features` representation, because this representation
# makes classification easier. This representation organizes images in a more "useful" and
# "semantic" way than pixels.
#
# Let me be more specific:
# this set of `features` was trained on image classification. It turns out that
# **these features can be useful for performing other image-related tasks as well!**
# That is, if we want to perform an image classification task of our own (for example,
# classifying cancer biopsies, which is nothing like what AlexNet was trained to do),
# we might compute these AlexNet features, and then train a small model on top of those
# features. We replace the `classifier` portion of `AlexNet`, but keep its `features`
# portion intact.
#
# Somehow, through being trained on one type of image classification problem, AlexNet
# learned something general about representing images for the purposes of other
# classification tasks.
#
# ### AlexNet First Convolutions
#
# Here is the first convolution of AlexNet, applied to our image.

# %%
alexNetConv = alexNet.features[0]
y = alexNetConv(x)
y.shape
# Out:
# torch.Size([1, 64, 86, 51])

# %% [markdown]
# The output is a $1 \times 64 \times 86 \times 51$ tensor.

# %%
y = y.detach().numpy()
y = (y - y.min()) / (y.max() - y.min())
y.shape
# Out:
# (1, 64, 86, 51)

# %% [markdown]
# We can visualize each channel independently.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10,10))
for i in range(64):
    plt.subplot(8, 8, i+1)
    plt.imshow(y[0, i])

# %% [markdown]
# What happens to the output if you when we try to use other images? Specifically what happens to the size of the feature tensor when you use a cat image vs the dog image? What changes? What stays the same?

# %% [markdown]
# ## Applying AlexNet on a Dataset
# In order to use transfer learning with AlexNet on a new dataset we will have to keep in mind how AlexNet was trained. AlexNet was trained on images of 3 x 224 x 224 images from the ImageNet dataset. These images are of higher resolution than what we have seen until now and are in colour. Hence, it would take significant effort to apply AlexNet to MNIST data, instead we will use another datasets.

# %% [markdown]
# ### Data Loading from a File
# To load our data we will use PyTorch's ImageFolder class which makes things a lot easier by allowing you to load data from a directory. For example, the training images are all stored in a directory path that looks like this:
#
# /datadir
#
#     /train
#         /class1
#         /class2
#         .
#         .
#     /val
#         /class1
#         /class2
#         .
#         .
#     /test
#         /class1
#         /class2
#         .
#         .
#
# You will need to mount your Google Drive to make this work with Colab.
#
# **It is important to copy the dataset in the host's local storage (e.g., unzip in `/root/datasets`)**

# %%
  # mount our Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !unzip '/content/drive/My Drive/Colab Notebooks/Flower_Data_Large.zip' -d '/root/datasets'

# %% [markdown]
# If you have not uploaded the dataset to your google drive use this method.

# %%
! pip install wget
# Out:
# Collecting wget
#   Downloading https://files.pythonhosted.org/packages/47/6a/62e288da7bcda82b935ff0c6cfe542970f04e29c756b0e147251b2fb251f/wget-3.2.zip
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-cp36-none-any.whl size=9682 sha256=d4546c038760c42ab2f7c60c63f0852aee60391ccd6015712fa094626543a6c1
#   Stored in directory: /root/.cache/pip/wheels/40/15/30/7d8f7cea2902b4db79e3fea550d7d7b85ecb27ef992b618f3f
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
# !wget 'https://www.eecg.utoronto.ca/~hadizade/APS360_S20/Flower_Data_Large.zip'
# Out:
# --2020-06-03 18:46:52--  https://www.eecg.utoronto.ca/~hadizade/APS360_S20/Flower_Data_Large.zip
# Resolving www.eecg.utoronto.ca (www.eecg.utoronto.ca)... 128.100.10.90
# Connecting to www.eecg.utoronto.ca (www.eecg.utoronto.ca)|128.100.10.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 229487055 (219M) [application/zip]
# Saving to: ‘Flower_Data_Large.zip’
#
# Flower_Data_Large.z 100%[===================>] 218.86M  16.2MB/s    in 15s
#
# 2020-06-03 18:47:08 (15.0 MB/s) - ‘Flower_Data_Large.zip’ saved [229487055/229487055]

# %%
# !unzip 'Flower_Data_Large.zip' -d '/root/datasets'
# Out:
# Archive:  Flower_Data_Large.zip
#    creating: /root/datasets/Flower_Data_Large/train/
#    creating: /root/datasets/Flower_Data_Large/train/daisy/
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/.DS_Store
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/100080576_f52e8ee070_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10140303196_b88d3d6cec.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10172379554_b296050f82_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10172567486_2748826a8b.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10172636503_21bededa75_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/102841525_bd6628ae3c.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1031799732_e7f4008c03.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10391248763_1d16681106_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10437754174_22ec990b77_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10437770546_8bb6f7bdd3_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10437929963_bc13eebe0c.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10466290366_cc72e33532.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10466558316_a7198b87e2.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10555749515_13a12a026e.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10555815624_dc211569b0.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10555826524_423eb8bf71_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10559679065_50d2b16f6d.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/105806915_a9c13e2106_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10712722853_5632165b04.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/107592979_aaa9cdfe78_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10770585085_4742b9dac3_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10841136265_af473efc60.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10993710036_2033222c91.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10993818044_4c19b86c82.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/10994032453_ac7f8d9e2e.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/11023214096_b5b39fab08.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/11023272144_fce94401f2_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/11023277956_8980d53169_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/11124324295_503f3a0804.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1140299375_3aa7024466.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/11439894966_dca877f0cd.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1150395827_6f94a5c6e4_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/11642632_1e7627a2cc.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/11834945233_a53b7a92ac_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/11870378973_2ec1919f12.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/11891885265_ccefec7284_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/12193032636_b50ae7db35_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/12348343085_d4c396e5b5_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/12585131704_0f64b17059_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/12601254324_3cb62c254a_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1265350143_6e2b276ec9.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/12701063955_4840594ea6_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1285423653_18926dc2c8_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1286274236_1d7ac84efb_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/12891819633_e4c82b51e8.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1299501272_59d9da5510_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1306119996_ab8ae14d72_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1314069875_da8dc023c6_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1342002397_9503c97b49.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/134372449_0f7166d96c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/134409839_71069a95d1_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1344985627_c3115e2d71_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/13491959645_2cd9df44d6_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1354396826_2868631432_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1355787476_32e9f2a30b.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/13583238844_573df2de8e_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1374193928_a52320eafa.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/13826249325_f61cb15f86_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/13901930939_a7733c03f0_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1392131677_116ec04751.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1392946544_115acbb2d9.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/13953307149_f8de6a768c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1396526833_fb867165be_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/13977181862_f8237b6b52.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14021430525_e06baf93a9.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14073784469_ffb12f3387_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14087947408_9779257411_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14088053307_1a13a0bf91_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14114116486_0bb6649bc1_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14147016029_8d3cf2414e.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14163875973_467224aaf5_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14167534527_781ceb1b7a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14167543177_cd36b54ac6_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14219214466_3ca6104eae_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14221836990_90374e6b34.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14221848160_7f0a37c395.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14245834619_153624f836.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14264136211_9531fbc144.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14272874304_47c0a46f5a.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14307766919_fac3c37a6b_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/14330343061_99478302d4_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/144076848_57e1d662e3_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/144099102_bf63a41e4f_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1441939151_b271408c8d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/144603918_b9de002f60_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/147068564_32bb4350cc.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/15207766_fc2f1d692c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/153210866_03cc9f2f36.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/154332674_453cea64f4.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/158869618_f1a6704236_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/162362896_99c7d851c8_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/162362897_1d21b70621_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/163978992_8128b49d3e_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1656856503_447e5b0f03.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/169371301_d9b91a2a42.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/171972704_389cf7a953.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/172882635_4cc7b86731_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/172967318_c596d082cc.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/173350276_02817aa8d5.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/174131220_c853df1287.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/175106495_53ebdef092_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/176375506_201859bb92_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/181007802_7cab5ee78e_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1879567877_8ed2a5faa7_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/1955336401_fbb206d6ef_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2001380507_19488ff96a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2019064575_7656b9340f_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2045022175_ad087f5f60_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2057816617_18448093d0_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2077865117_9ed85191ae_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2087343668_ef4fb95787_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/21652746_cc379e0eea_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2213954589_c7da4b1486.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2331133004_582772d58f_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2346726545_2ebce2b2a6.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2349640101_212c275aa7.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2351206867_084e57bd97.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2365428551_39f83f10bf_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2408024540_37f0be7cc0_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2454280135_ac3aa75cdc_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2454280137_e1637536ae_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2473825306_62fd5f8785_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2476937534_21b285aa46_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2479956481_8d1a9699be_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2480569557_f4e1f0dcb8_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2481823240_eab0d86921.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2482982436_a2145359e0_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2488902131_3417698611_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2498632196_e47a472d5a.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2509545845_99e79cb8a2_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2511306240_9047015f2d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2513618768_ff7c004796_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2514748602_343d4727c0_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2520369272_1dcdb5a892_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2521408074_e6f86daf21_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/253426762_9793d43fcd.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/25360380_1a881a5648.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2536529152_33ef3ee078_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2538504987_fe524b92a8_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2539552964_921cf645ba_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2551708158_1f10e81e11.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2556503265_63ae6b9e0e_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2561352120_7961d8263f.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2561371688_c80a4fe957_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2567033807_8e918c53d8_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2573240560_ff7ffdd449.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2578695910_5ab8ee17c1_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2579018590_74359dcf1a_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2581171297_b0a249b92b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2590291468_2635d3e4e0_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2599662355_7782218c83.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2607132536_d95198e619_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2611119198_9d46b94392.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2612704455_efce1c2144_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2617111535_54c2ac8462.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2619413565_61a6cd3ac9_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2621723097_736febb4a4_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2627815904_919373e7f5.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2632216904_274aa17433.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2635314490_e12d3b0f36_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2641151167_3bf1349606_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2641979584_2b21c3fe29_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2642408410_61545fdc83_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2646438199_b309cffd65_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2649404904_b7a91991bb_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2666572212_2caca8de9f_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/267148092_4bb874af58.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2713919471_301fcc941f.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2812442552_3eed5fb9f2_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2828733818_1c1ed0089d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2838487505_6c3b48efa5_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2862944799_45bc8e7302.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/286875003_f7c0e1882d.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2877860110_a842f8b14a_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2889325612_f2fc403ff0_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2901376034_cdb4bac26b_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/2908212142_5437fa67ff_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/294451721_5106537b34.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/299129811_d6ebda9970.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/301964511_fab84ea1c1.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3025866885_22fb0b61c6_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/302782756_d35cb3e468.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/305160642_53cde0f44f.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3080880039_4f1bd592e5_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3084924076_4d5c5711af_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3098641292_76c908ba1f_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3117644024_1cbb59a509_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3275951182_d27921af97_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3285641623_da0e47f49a.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3310644753_5607eb96a4_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3326037909_b5ae370722_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3336704121_cfeb67a7d7.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3337536080_1db19964fe.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3337643329_accc9b5426.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3338077096_3a8ed0e2bc_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3356112863_75da8bca2c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3379332157_04724f6480.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3386988684_bc5a66005e.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3410906335_37e8a24b1c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3415180846_d7b5cced14_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3440366251_5b9bdf27c9_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3445110406_0c1616d2e3_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3450822975_7e77d67636_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3456403987_5bd5fa6ece_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3463313493_9497aa47e5_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3468498624_d082f99e98.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3474942718_c418dae6f1.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3475870145_685a19116d.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3483303007_42e3f90da7.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3491933306_43cfe2cfbe.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3494265422_9dba8f2191_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3504430338_77d6a7fab4_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3506866918_61dd5fc53b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3533954656_79156c8473.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3546455114_cd2dea5e02.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3552074420_2a0a7166db_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3588872598_e0f9a1d2a1_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3598615130_578ed30e5f.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3611577717_f3a7a8c416_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3625257860_33efeef614_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3627678863_557552c879_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3628485766_4ff937954a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3633489595_a037a9b7a4_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3637428148_a1dcccafa9_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3639009391_0f910681b7.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3640845041_80a92c4205_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3661613900_b15ca1d35d_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/367020749_3c9a652d75.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3695826945_9f374e8a00_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3699235066_fc09a02dfe_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3703643767_dee82cdef9_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3704305945_a80e60e2f6_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3704306975_75b74497d8.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3706420943_66f3214862_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3711723108_65247a3170.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3711892138_b8c953fdc1_z.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3713290261_8a66de23ab.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3717746329_53f515c6a6_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3720632920_93cf1cc7f3_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3750250718_eb61146c5f.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3750771898_cfd50090ba_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3758221664_b19116d61f.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3764116502_f394428ee0_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3773181799_5def396456.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3780380240_ef9ec1b737_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3848258315_ed2fde4fb4.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3861452393_14d2f95157_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3900172983_9312fdf39c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/391364010_4b0942d400_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/391364011_5beaaa1ae2_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3939135368_0af5c4982a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3957488431_52a447c0e8_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3962240986_0661edc43a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3963330924_6c6a3fa7be_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3975010332_3209f9f447_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/3999978867_c67c79597f_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4065883015_4bb6010cb7_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4085794721_7cd88e0a6c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4117918318_3c8935289b_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4131565290_0585c4dd5a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/413815348_764ae83088.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4141147800_813f660b47.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4144275653_7c02d47d9b.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/422094774_28acc69a8b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4222584034_8964cbd3de.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4229503616_9b8a42123c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4258408909_b7cc92741c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4268817944_cdbdb226ae.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4276898893_609d11db8b.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4278442064_a5a598524b_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4281102584_c548a69b81_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4286053334_a75541f20b_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4301689054_20519e5b68.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4318007511_e9f4311936_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/433037739_6a030e5912.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4333085242_bbeb3e2841_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/433837534_1dbf798b73.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/43474673_7bb4465a86.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/435283392_72e4c5b5d6_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/437859108_173fb33c98.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4407065098_ef25f1ccac_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4413849849_b8d2f3bcf1_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4432271543_01c56ca3a9.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4434592930_6610d51fca_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4440480869_632ce6aff3_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/446484749_4044affcaf_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4482623536_b9fb5ae41f_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4496202781_1d8e776ff5_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/450128527_fd35742d44.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4511693548_20f9bd2b9c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/452854574_59492f119a_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4534460263_8e9611db3c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4538877108_3c793f7987_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4540555191_3254dc4608_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4544110929_a7de65d65f_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4561871220_47f420ca59_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4563059851_45a9d21a75.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4565255237_9ba29c4d4e_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4581199679_867652c3f1_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4598422221_b37313a3e3_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/459931395_24bf6531fe_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4610018126_21f438d2dc_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4613992315_143ccc2a10_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4646886118_b5c5ceaf6d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4654579740_6671a53627_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4657354814_f368762c53_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4666648087_b10f376f19.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4668543441_79040ca329_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4669117051_ce61e91b76.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4683997791_56e7d3c03c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4694730335_2553e77aa5_z.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4694734757_5c563d38dd_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4697206799_19dd2a3193_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4724713781_d169f98a35.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4727955343_0bb23ac4ae.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4746633946_23933c0810.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4753134939_8e87649db6.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4757448834_a29a9538c9_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/476856232_7c35952f40_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/476857510_d2b30175de_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4792826628_aa5e5a9804_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4814515275_6e25a6c18f.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4820415253_15bc3b6833_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4837182901_69a6cc782b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/483886997_27ee798327.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4851353993_2cbbbd1040_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4858518329_7563eb0baa_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4861391074_c3e122dab0_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4865691548_00319261b8.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/488202750_c420cbce61.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4890424315_6a59696357_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4897587985_f9293ea1ed.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4923279674_e7f8e70794_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/495098110_3a4bb30042_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/498159452_b71afd65ba.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/4993492878_11fd4f5d12.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5014137563_d03eb0ed75_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5054771689_00dd40b971_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5058708968_8bdcd29e63_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/506018088_4f7a15a7c5_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/506348009_9ecff8b6ef.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/506493250_e9ca42fe3d.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5087720485_c0914fb623.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/510844526_858b8fe4db.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5109508979_68e3530791_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5110105726_53eb7a93be_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5110107234_12ddc0206b_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5110109540_beed4ed162_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5110110938_9da91455c4_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/512177035_70afc925c8.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/512477177_d9004cbcf1_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5133243796_44de429de5_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5135131051_102d4878ca_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/515112668_a49c69455a.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/517054463_036db655a1_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/517054467_d82d323c33_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/519880292_7a3a6c6b69.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/520752848_4b87fb91a4.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/521762040_f26f2e08dd.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/525271784_013ddccd1b_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/525780443_bba812c26a_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/530738000_4df7e4786b.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/534547364_3f6b7279d2_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/538920244_59899a78f8_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5434742166_35773eba57_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5434901893_4550be3f84_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5434913005_409c1e8b56_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5434914569_e9b982fde0_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5435513198_90ce39f1aa_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5435521200_92029bbe2b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5435522104_1d6a61b431_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/54377391_15648e8d18.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5459481183_18d2d49e44_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5512287917_9f5d3f0f98_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5547758_eea9edfd54_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5561775629_a2b709b3a4_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5574421625_61b1f49b3f_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5577555349_2e8490259b.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5586977262_6b24412805_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5602738326_97121e007d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5608389827_a42a46f760.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5623010186_796ca8d29a.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5626784099_b36dd3fb11_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5626895440_97a0ec04c2_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5632774792_0fa33d17eb_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5665834973_76bd6c6523_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5665838969_fe217988b9_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5673551_01d1ea993e_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5673728_71b8cb57eb.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5679288570_b4c52e76d5.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5684911529_88a7ae32ba_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5693459303_e61d9a9533.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5700781400_65761f3fce.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5714327423_50af0cffe9.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5722473541_ffac1ae67e_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5739768868_9f982684f9_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5765646947_82e95a9cc9_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5769217520_c90efc3c93_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5773652803_574b51414f_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5794835_d15905c7c8_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5794839_200acd910c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5795159787_ebb51a5e75.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5796562389_ae43c83317_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5809489674_5659b3ae5d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5811226952_4650ed70ae_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5853276960_d08f90fff6.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5869147563_66fb88119d.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5874818796_3efbb8769d.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5876455546_32049e5585.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5881907044_92a85a05c8_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5883162120_dc7274af76_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5884807222_22f5326ba8_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5885826924_38fdc6bcaa_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5944315415_2be8abeb2f_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5948835387_5a98d39eff_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5973488341_50bdf6cee3_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5973491805_556bba93cc.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5981645737_29eceac291_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/5997702776_c7bc37aa6b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6054952060_c88612f3c5_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6089825811_80f253fbe1.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6095817094_3a5b1d793d.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6136947177_47ff445eb4_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6148728633_27afc47b0c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6207492986_0ff91f3296.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6208851904_9d916ebb32_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6210664514_f1d211217a.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6299498346_b9774b6500.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6299910262_336309ffa5_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6323721068_3d3394af6d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6480809573_76a0074b69_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6480809771_b1e14c5cc2_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6529588249_d9cbe68aab_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6596277835_9f86da54bb.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/676120388_28f03069c3.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6776075110_1ea7a09dd4_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6864242336_0d12713fe5_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6884975451_c74f445d69_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6910811638_aa6f17df23.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6950173662_5e9473003e_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/695778683_890c46ebac.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/6978826370_7b9aa7c7d5.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/705422469_ffa28c566d.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7066602021_2647457985_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7133935763_82b17c8e1b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7189043225_2fe781439a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7191221492_610035de7c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7199968650_72afc16d31_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/721595842_bacd80a6ac.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7227973870_806d9d3e42_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7288989324_c25d9febbf.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7320089276_87b544e341.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7335886184_d06a83f640.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7358085448_b317d11cd5.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7377004908_5bc0cde347_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7410356270_9dff4d0e2e_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7416083788_fcb4c4f27e_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7454630692_ab2d67dd18_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7538403124_f2fc48750a.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/754248840_95092de274.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/754296579_30a9ae018c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7568630428_8cf0fc16ff_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7629784968_b953501902_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7630511450_02d3292e90.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7630517248_98fb8bee1f_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7630520686_e3a61ac763.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7633425046_8293e3d0e9_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7669550908_bc5a11276f_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7702332000_3f21ef4571_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7749368884_1fc58c67ff_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7790614422_4557928ab9_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/7924174040_444d5bbb8a.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/799952628_bf836677fa_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/799964360_7e07a227ea_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8008258043_5457dd254b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8021540573_c56cf9070d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8063844363_db3f4dea85.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8071646795_2fdc89ab7a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8085329197_41d53a21e2_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8094774544_35465c1c64.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8120563761_ed5620664f_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8127252886_96558c23d1.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/813445367_187ecf080a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8348621545_8f02b82662_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/835750256_3f91a147ef_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8382667241_0f046cecdb_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8383753520_8391dd80ee_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8446495985_f72d851482.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8489463746_a9839bf7e4.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8616684075_71923bb771_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8619103877_d8c82c5f34_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8645839873_0151fb92bf_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8671824531_64b816949e_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8681746439_d6beeefbf9.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8694909523_3ca25d449d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8696022686_1f8d62c5cb_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8706810197_17b6c1f1e7.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8708143485_38d084ac8c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8709110478_60d12efcd4_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8709535323_a6bea3e43f.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8710109684_e2c5ef6aeb_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8718637649_87a0d85190_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8719756744_34a5a83976_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8740807508_0587f5b7b7.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8742143296_fed9fa007c.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8759177308_951790e00d_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8882282142_9be2524d38_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8887005939_b19e8305ee.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8932490012_cc08e690ba_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8938566373_d129e7af75.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8964198962_6d8593b533.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/8983779970_9d3a6a3bf2_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9054268881_19792c5203_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9094631844_1a6abca29e.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/909609509_a05ccb8127.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9120905231_329598304e.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9146733107_98b15d3892_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9158041313_7a6a102f7a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9161647994_e39b65cb9c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9175280426_40ecc395b8_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9180706736_092d43088c.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9204730092_a7f2182347.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9242705328_eee8402a8d.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9244082319_b1f7e2d8b0_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9286947622_4822f4fc21.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9299302012_958c70564c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9310226774_d1b8f5d9c9.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9321854387_5f77c926cb_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9345273630_af3550031d.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9346508462_f0af3163f4.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9350942387_5b1d043c26_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9467543719_c4800becbb_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9489270024_1b05f08492_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9496209717_25a6ebdab6_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9515186037_3be48fe68f.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9529916092_de70623523_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9593034725_0062f0d24e_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9595857626_979c45e5bf_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9611923744_013b29e4da_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/9922116524_ab4a2533fe_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/daisy/99306615_739eb94b9e_m.jpg
#    creating: /root/datasets/Flower_Data_Large/train/dandelion/
#   inflating: /root/datasets/Flower_Data_Large/train/dandelion/.DS_Store
#   inflating: /root/datasets/Flower_Data_Large/train/dandelion/10043234166_e6dd915111_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/dandelion/10200780773_c6051a7d71_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/dandelion/10294487385_92a0676c7d_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/dandelion/10437652486_aa86c14985.jpg
#   inflating: /root/datasets/Flower_Data_Large/train/dandelion/10443973_aeb97513fc_m.jpg
# ...
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20078409301_aa8061bd0b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20148493928_9f75a99783.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20156280765_a6baea3176.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20171662239_f69b6c12bd_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20183028616_beb937e75c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20183071136_c297e74fcc_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20258015499_93b9951800_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20342824594_9740b7b160.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20344282483_05abb0b837.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20344366953_44fb51051b.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20406385204_469f6749e2_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20407896403_a50fef58ac_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20410533613_56da1cce7c.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20410697750_c43973d1eb.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20481273479_d459834a3e_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20621698991_dcb323911d.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20658775992_1619cd0a9b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20667988875_6e73ac2879_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20704967595_a9c9b8d431.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20753711039_0b11d24b50_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20777358950_c63ea569a1.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20777375650_ef854bf645.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20871601265_daa4be4291_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20905163782_312e2c3bda_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20965412955_2c640b13bd.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20972862281_5367f4af88.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/20972866151_e6a928b00a.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/21134000558_d7d6c9b1fe_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/21349789961_18ba1af5b7_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/21374127408_5ffbe87bb2.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/21518663809_3d69f5b995_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/21728822928_9f6817325a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/21796333524_38fc8e0ab5_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/21821266773_7113d34c35_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/21984860006_20dfacea1c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/21995435890_e5672244a4_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22183521655_56221bf2a4_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22183529245_ce13557515_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22203670478_9ec5c2700b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22255608949_172d7c8d22_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22405882322_d4561f8469_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22405887122_75eda1872f_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22416421196_caf131c9fa_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22419079265_8902cddb7d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22429146402_332fa2fc72_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22429946721_e17a12cb39_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22478719251_276cb094f9_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22686342422_c0b9e2f38e.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22755811033_cd17b109e0.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/22992257000_76dbc599e7_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/23204123212_ef32fbafbe.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/23247483352_0defc7a6dc_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/23286304156_3635f7de05.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/23356825566_f5885875f2.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/23645265812_24352ff6bf.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/sunflowers/23894449029_bf0f34d35d_n.jpg
#    creating: /root/datasets/Flower_Data_Large/val/tulips/
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14487762578_baba13d16a_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14487943607_651e8062a1_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14491997336_36ba524713.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14651383746_419dc73634_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14651385476_7ccb20e594_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14671196461_b725727229_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14674067742_73c2602aa6_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14674071872_2df55466d5_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14674388855_2da18e375a_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14674389605_df3c0bcfa1_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14746916178_40403cc57e.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14836105101_1d07520932_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14861513337_4ef0bfa40d.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/14866400927_3a59899df3_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15029962436_3e50c1f30f_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15049902081_dd85361f8c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15052586652_56a82de133_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15082212714_ff87e8fcb1_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15090146325_b7e1249e60.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15147464747_594599c855_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15147473067_7c5498eb0e_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15149373026_93aacc65c5.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15275144259_f9a18ec9cb.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15275190769_0ed7bbf490.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15275199229_962387f24d.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15275478257_fbd5850708_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15275504998_ca9eb82998.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15452909878_0c4941f729_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15458787091_3edc6cd1eb.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15516715153_08abc9bb20_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15516736553_b169b67195_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15632065904_0d9caf174b.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15647243236_2778501cf5_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15756524087_823cf86bd8_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15881325303_f00807a051_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15922772266_1167a06620.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/15976769174_1d50f46ca1_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16055807744_000bc07afc_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16062072523_1be3c0b61f.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16074109313_2cc14c7d16.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16098264209_38fe491093.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16110795216_b3e44697b4_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16138212287_643bf336e1_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16139439153_fbdee29a10_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16169741783_deeab1a679_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16265876844_0a149c4f76.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16265883604_92be82b973.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16282277874_b92776b194.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16283125269_4cfae953f1.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16303377824_6e9128b4bd.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16309287412_5cc4d58bd1_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16471277547_a0a5509377_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16485607329_e66d5960bc_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16506668270_b823935dc3.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16582481123_06e8e6b966_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16594995743_ce72c61201_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16644790896_7b296ecd67_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16645809126_613b1e3ebe_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16670377091_87987f50a4_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16677199221_eab3f22378_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16677542612_a78a8ca8b3_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16680927427_07ca6e4552_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16680930777_7e7f292fc5_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16680998737_6f6225fe36.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16700863150_ddaa4d89b4_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16702117379_c25bff70e9.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16702188449_3dacce90b2_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16711791713_e54bc9c1af_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16717320956_d4b00807f2.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16732302779_8aa56f255d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16751015081_af2ef77c9a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16765283686_0315ae00a8.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16862349256_0a1f91ab53.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16862351376_f0fcc6fc91_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16862374316_4135908d4c_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16862422576_5226e8d1d0.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16904202259_8f45d045c3_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16907559551_05ded87fb2_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16930105456_8b826dc4a8_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16930121391_a4092ecf00_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16937554595_3e1de22f9c.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16938892686_3613ea68e8_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16951623209_00fb7ec1b1_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/16986144192_55e0e6c152.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17012955700_7141d29eee.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17066862602_7530f21efe.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17066864992_1cbc4fc908.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17078576150_6f272ce73f_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17078716890_68e0723389_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17094167287_865840060d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17146928665_600fa3a1f1_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17159349572_c0c51599f7_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17159816388_deafbebdb0.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17165583356_38cb1f231d_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17167151059_a53bfe0b02.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17189456156_6fc1067831.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17189526216_fa24dd541a_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17198868382_697b23c715_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17199496791_3caaf5e278_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17199499591_67b64b21ed_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17202535346_ab828e779b.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17224410762_402455ed8f.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17282288501_e8738c9cfb_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17295127995_62eff434fe_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17309951996_552d632cbb_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17318339476_54479b6660_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17324469461_2b318aff8d_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17408197905_829c4d7940_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17469578564_35a8360f58.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17719248689_cfd5d2f228_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17720403638_94cfcd8d5c_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17781940352_a45e4289a5.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17844723633_da85357fe3.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17862445825_f7031d6f26.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17907238905_1ae121f8d9_m.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17908793211_ff0f1f81d3_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/17994129033_bbd0acba62_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/18245124970_e68fd3f3c3.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/18270448366_d5676dec64_z.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/18378581986_5cd1494d08_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/18378582936_ee7085c850.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/18406629611_4d1edcf23b_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/19413898445_69344f9956_n.jpg
#   inflating: /root/datasets/Flower_Data_Large/val/tulips/19425920580_cdc8f49aed_n.jpg

# %%
import time
import os
import numpy as np
import torch

import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt

# %%
# define training and test data directories
data_dir = '/root/datasets/Flower_Data_Large'
train_dir = os.path.join(data_dir, 'train/')
val_dir = os.path.join(data_dir, 'val/')

# classes are folders in each directory with these names
classes = ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
# load and transform data using ImageFolder

# resize all images to 224 x 224
data_transform = transforms.Compose([transforms.RandomResizedCrop(224), 
                                      transforms.ToTensor()])

train_data = datasets.ImageFolder(train_dir, transform=data_transform)
val_data = datasets.ImageFolder(val_dir, transform=data_transform)

# print out some data stats
print('Num training images: ', len(train_data))
print('Num validation images: ', len(val_data))
# Out:
# Num training images:  3130
# Num validation images:  540

# %%
# define dataloader parameters
batch_size  = 256
num_workers = 0

# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
                                           num_workers=num_workers, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, 
                                          num_workers=num_workers, shuffle=True)

# %%
# Visualize some sample data

# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    plt.imshow(np.transpose(images[idx], (1, 2, 0)))
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# ### AlexNet Implementation

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim #for gradient descent

# alexnet
import torchvision.models

torch.manual_seed(1) # set the random seed


# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# confirm output from AlexNet feature extraction
alexNet = torchvision.models.alexnet(pretrained=True)
features = alexNet.features(images)
features.shape
# Out:
# torch.Size([256, 256, 6, 6])

# %%
#Artifical Neural Network Architecture
class ANNClassifier(nn.Module):
    def __init__(self):
        super(ANNClassifier, self).__init__()
        self.fc1 = nn.Linear(256 * 6 * 6, 10)
        self.fc2 = nn.Linear(10, 5)

    def forward(self, x):
        x = x.view(-1, 256 * 6 * 6) #flatten feature data
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
def get_accuracy(model, train=False):
    if train:
        data_loader = train_loader
    else:
        data_loader = val_loader

    correct = 0
    total = 0
    for imgs, labels in data_loader:
        
         
        #############################################
        #To Enable GPU Usage
        if use_cuda and torch.cuda.is_available():
          imgs = imgs.cuda()
          labels = labels.cuda()
        #############################################
        
        output = model(ALNC(imgs))
        
        #select index with maximum prediction score
        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]
    return correct / total

# %%
def train(model, data, batch_size=20, num_epochs=1):
    #train_loader = torch.utils.data.DataLoader(data, batch_size=batch_size)
    # train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
                                           #num_workers=num_workers, shuffle=True)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

    iters, losses, train_acc, val_acc = [], [], [], []

    # training
    n = 0 # the number of iterations
    start_time=time.time()
    for epoch in range(num_epochs):
        mini_b=0
        mini_batch_correct = 0
        Mini_batch_total = 0
        for imgs, labels in iter(train_loader):
          
            
            #############################################
            #To Enable GPU Usage
            if use_cuda and torch.cuda.is_available():
              imgs = imgs.cuda()
              labels = labels.cuda()
            #############################################

          #### ALNC is alexNet.features (AlexNet without classifier) ####
          
            out = model(ALNC(imgs))             # forward pass
            loss = criterion(out, labels) # compute the total loss
            loss.backward()               # backward pass (compute parameter updates)
            optimizer.step()              # make the updates for each parameter
            optimizer.zero_grad()         # a clean up step for PyTorch



            ##### Mini_batch Accuracy ##### We don't compute accuracy on the whole trainig set in every iteration!
            pred = out.max(1, keepdim=True)[1]
            mini_batch_correct = pred.eq(labels.view_as(pred)).sum().item()
            Mini_batch_total = imgs.shape[0]
            train_acc.append((mini_batch_correct / Mini_batch_total))
           ###########################

          # save the current training information
            iters.append(n)
            losses.append(float(loss)/batch_size)             # compute *average* loss
            val_acc.append(get_accuracy(model, train=False))  # compute validation accuracy
            n += 1
            mini_b += 1
            print("Iteration: ",n,'Progress: % 6.2f ' % ((epoch * len(train_loader) + mini_b) / (num_epochs * len(train_loader))*100),'%', "Time Elapsed: % 6.2f s " % (time.time()-start_time))


        print ("Epoch %d Finished. " % epoch ,"Time per Epoch: % 6.2f s "% ((time.time()-start_time) / (epoch +1)))


    end_time= time.time()
    # plotting
    plt.title("Training Curve")
    plt.plot(iters, losses, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Training Curve")
    plt.plot(iters, train_acc, label="Training")
    plt.plot(iters, val_acc, label="Validation")    
    plt.xlabel("Iterations")
    plt.ylabel("Validation Accuracy")
    plt.legend(loc='best')
    plt.show()

    train_acc.append(get_accuracy(model, train=True))
    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(val_acc[-1]))
    print ("Total time:  % 6.2f s  Time per Epoch: % 6.2f s " % ( (end_time-start_time), ((end_time-start_time) / num_epochs) ))

# %%
# !nvidia-smi
# Out:
# Wed Jun  3 18:47:24 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
use_cuda = True

model = ANNClassifier()
ALNC = alexNet.features

if use_cuda and torch.cuda.is_available():
  ALNC.cuda()
  model.cuda()
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')
  
#proper model
train(model, [], batch_size=batch_size, num_epochs=10)
# Out:
# CUDA is available!  Training on GPU ...
# Iteration:  1 Progress:   0.77  % Time Elapsed:   3.56 s
# Iteration:  2 Progress:   1.54  % Time Elapsed:   6.91 s
# Iteration:  3 Progress:   2.31  % Time Elapsed:  10.34 s
# Iteration:  4 Progress:   3.08  % Time Elapsed:  13.71 s
# Iteration:  5 Progress:   3.85  % Time Elapsed:  17.06 s
# Iteration:  6 Progress:   4.62  % Time Elapsed:  20.46 s
# Iteration:  7 Progress:   5.38  % Time Elapsed:  23.81 s
# Iteration:  8 Progress:   6.15  % Time Elapsed:  27.14 s
# Iteration:  9 Progress:   6.92  % Time Elapsed:  30.53 s
# Iteration:  10 Progress:   7.69  % Time Elapsed:  33.97 s
# Iteration:  11 Progress:   8.46  % Time Elapsed:  37.32 s
# Iteration:  12 Progress:   9.23  % Time Elapsed:  40.68 s
# Iteration:  13 Progress:  10.00  % Time Elapsed:  43.16 s
# Epoch 0 Finished.  Time per Epoch:  43.16 s
# Iteration:  14 Progress:  10.77  % Time Elapsed:  46.53 s
# Iteration:  15 Progress:  11.54  % Time Elapsed:  49.88 s
# Iteration:  16 Progress:  12.31  % Time Elapsed:  53.31 s
# Iteration:  17 Progress:  13.08  % Time Elapsed:  56.71 s
# Iteration:  18 Progress:  13.85  % Time Elapsed:  60.11 s
# Iteration:  19 Progress:  14.62  % Time Elapsed:  63.57 s
# Iteration:  20 Progress:  15.38  % Time Elapsed:  66.89 s
# Iteration:  21 Progress:  16.15  % Time Elapsed:  70.28 s
# Iteration:  22 Progress:  16.92  % Time Elapsed:  73.69 s
# Iteration:  23 Progress:  17.69  % Time Elapsed:  77.07 s
# Iteration:  24 Progress:  18.46  % Time Elapsed:  80.43 s
# Iteration:  25 Progress:  19.23  % Time Elapsed:  83.81 s
# Iteration:  26 Progress:  20.00  % Time Elapsed:  86.27 s
# Epoch 1 Finished.  Time per Epoch:  43.14 s
# Iteration:  27 Progress:  20.77  % Time Elapsed:  89.63 s
# Iteration:  28 Progress:  21.54  % Time Elapsed:  93.05 s
# Iteration:  29 Progress:  22.31  % Time Elapsed:  96.40 s
# Iteration:  30 Progress:  23.08  % Time Elapsed:  99.65 s
# Iteration:  31 Progress:  23.85  % Time Elapsed:  102.96 s
# Iteration:  32 Progress:  24.62  % Time Elapsed:  106.32 s
# Iteration:  33 Progress:  25.38  % Time Elapsed:  109.72 s
# Iteration:  34 Progress:  26.15  % Time Elapsed:  113.13 s
# Iteration:  35 Progress:  26.92  % Time Elapsed:  116.48 s
# Iteration:  36 Progress:  27.69  % Time Elapsed:  119.82 s
# Iteration:  37 Progress:  28.46  % Time Elapsed:  123.20 s
# Iteration:  38 Progress:  29.23  % Time Elapsed:  126.63 s
# Iteration:  39 Progress:  30.00  % Time Elapsed:  129.06 s
# Epoch 2 Finished.  Time per Epoch:  43.02 s
# Iteration:  40 Progress:  30.77  % Time Elapsed:  132.41 s
# Iteration:  41 Progress:  31.54  % Time Elapsed:  135.84 s
# Iteration:  42 Progress:  32.31  % Time Elapsed:  139.21 s
# Iteration:  43 Progress:  33.08  % Time Elapsed:  142.62 s
# Iteration:  44 Progress:  33.85  % Time Elapsed:  146.04 s
# Iteration:  45 Progress:  34.62  % Time Elapsed:  149.43 s
# Iteration:  46 Progress:  35.38  % Time Elapsed:  152.86 s
# Iteration:  47 Progress:  36.15  % Time Elapsed:  156.28 s
# Iteration:  48 Progress:  36.92  % Time Elapsed:  159.68 s
# Iteration:  49 Progress:  37.69  % Time Elapsed:  163.00 s
# Iteration:  50 Progress:  38.46  % Time Elapsed:  166.41 s
# Iteration:  51 Progress:  39.23  % Time Elapsed:  169.83 s
# Iteration:  52 Progress:  40.00  % Time Elapsed:  172.32 s
# Epoch 3 Finished.  Time per Epoch:  43.08 s
# Iteration:  53 Progress:  40.77  % Time Elapsed:  175.73 s
# Iteration:  54 Progress:  41.54  % Time Elapsed:  179.16 s
# Iteration:  55 Progress:  42.31  % Time Elapsed:  182.60 s
# Iteration:  56 Progress:  43.08  % Time Elapsed:  186.11 s
# Iteration:  57 Progress:  43.85  % Time Elapsed:  189.52 s
# Iteration:  58 Progress:  44.62  % Time Elapsed:  192.90 s
# Iteration:  59 Progress:  45.38  % Time Elapsed:  196.31 s
# Iteration:  60 Progress:  46.15  % Time Elapsed:  199.74 s
# Iteration:  61 Progress:  46.92  % Time Elapsed:  203.23 s
# Iteration:  62 Progress:  47.69  % Time Elapsed:  206.60 s
# Iteration:  63 Progress:  48.46  % Time Elapsed:  210.01 s
# Iteration:  64 Progress:  49.23  % Time Elapsed:  213.41 s
# Iteration:  65 Progress:  50.00  % Time Elapsed:  215.89 s
# Epoch 4 Finished.  Time per Epoch:  43.18 s
# Iteration:  66 Progress:  50.77  % Time Elapsed:  219.37 s
# Iteration:  67 Progress:  51.54  % Time Elapsed:  222.79 s
# Iteration:  68 Progress:  52.31  % Time Elapsed:  226.22 s
# Iteration:  69 Progress:  53.08  % Time Elapsed:  229.69 s
# Iteration:  70 Progress:  53.85  % Time Elapsed:  233.16 s
# Iteration:  71 Progress:  54.62  % Time Elapsed:  236.60 s
# Iteration:  72 Progress:  55.38  % Time Elapsed:  240.03 s
# Iteration:  73 Progress:  56.15  % Time Elapsed:  243.45 s
# Iteration:  74 Progress:  56.92  % Time Elapsed:  246.90 s
# Iteration:  75 Progress:  57.69  % Time Elapsed:  250.32 s
# Iteration:  76 Progress:  58.46  % Time Elapsed:  253.68 s
# Iteration:  77 Progress:  59.23  % Time Elapsed:  257.14 s
# Iteration:  78 Progress:  60.00  % Time Elapsed:  259.66 s
# Epoch 5 Finished.  Time per Epoch:  43.28 s
# Iteration:  79 Progress:  60.77  % Time Elapsed:  263.06 s
# Iteration:  80 Progress:  61.54  % Time Elapsed:  266.46 s
# Iteration:  81 Progress:  62.31  % Time Elapsed:  269.87 s
# Iteration:  82 Progress:  63.08  % Time Elapsed:  273.36 s
# Iteration:  83 Progress:  63.85  % Time Elapsed:  276.79 s
# Iteration:  84 Progress:  64.62  % Time Elapsed:  280.33 s
# Iteration:  85 Progress:  65.38  % Time Elapsed:  283.78 s
# Iteration:  86 Progress:  66.15  % Time Elapsed:  287.27 s
# Iteration:  87 Progress:  66.92  % Time Elapsed:  290.84 s
# Iteration:  88 Progress:  67.69  % Time Elapsed:  294.24 s
# Iteration:  89 Progress:  68.46  % Time Elapsed:  297.69 s
# Iteration:  90 Progress:  69.23  % Time Elapsed:  301.15 s
# Iteration:  91 Progress:  70.00  % Time Elapsed:  303.65 s
# Epoch 6 Finished.  Time per Epoch:  43.38 s
# Iteration:  92 Progress:  70.77  % Time Elapsed:  307.16 s
# Iteration:  93 Progress:  71.54  % Time Elapsed:  310.57 s
# Iteration:  94 Progress:  72.31  % Time Elapsed:  313.98 s
# Iteration:  95 Progress:  73.08  % Time Elapsed:  317.42 s
# Iteration:  96 Progress:  73.85  % Time Elapsed:  320.90 s
# Iteration:  97 Progress:  74.62  % Time Elapsed:  324.32 s
# Iteration:  98 Progress:  75.38  % Time Elapsed:  327.76 s
# Iteration:  99 Progress:  76.15  % Time Elapsed:  331.21 s
# Iteration:  100 Progress:  76.92  % Time Elapsed:  334.62 s
# Iteration:  101 Progress:  77.69  % Time Elapsed:  338.09 s
# Iteration:  102 Progress:  78.46  % Time Elapsed:  341.52 s
# Iteration:  103 Progress:  79.23  % Time Elapsed:  344.93 s
# Iteration:  104 Progress:  80.00  % Time Elapsed:  347.44 s
# Epoch 7 Finished.  Time per Epoch:  43.43 s
# Iteration:  105 Progress:  80.77  % Time Elapsed:  350.88 s
# Iteration:  106 Progress:  81.54  % Time Elapsed:  354.41 s
# Iteration:  107 Progress:  82.31  % Time Elapsed:  357.82 s
# Iteration:  108 Progress:  83.08  % Time Elapsed:  361.24 s
# Iteration:  109 Progress:  83.85  % Time Elapsed:  364.71 s
# Iteration:  110 Progress:  84.62  % Time Elapsed:  368.13 s
# Iteration:  111 Progress:  85.38  % Time Elapsed:  371.57 s
# Iteration:  112 Progress:  86.15  % Time Elapsed:  374.99 s
# Iteration:  113 Progress:  86.92  % Time Elapsed:  378.46 s
# Iteration:  114 Progress:  87.69  % Time Elapsed:  381.96 s
# Iteration:  115 Progress:  88.46  % Time Elapsed:  385.44 s
# Iteration:  116 Progress:  89.23  % Time Elapsed:  388.90 s
# Iteration:  117 Progress:  90.00  % Time Elapsed:  391.47 s
# Epoch 8 Finished.  Time per Epoch:  43.50 s
# Iteration:  118 Progress:  90.77  % Time Elapsed:  394.97 s
# Iteration:  119 Progress:  91.54  % Time Elapsed:  398.44 s
# Iteration:  120 Progress:  92.31  % Time Elapsed:  401.92 s
# Iteration:  121 Progress:  93.08  % Time Elapsed:  405.39 s
# Iteration:  122 Progress:  93.85  % Time Elapsed:  408.90 s
# Iteration:  123 Progress:  94.62  % Time Elapsed:  412.39 s
# Iteration:  124 Progress:  95.38  % Time Elapsed:  415.87 s
# Iteration:  125 Progress:  96.15  % Time Elapsed:  419.31 s
# Iteration:  126 Progress:  96.92  % Time Elapsed:  422.84 s
# Iteration:  127 Progress:  97.69  % Time Elapsed:  426.34 s
# Iteration:  128 Progress:  98.46  % Time Elapsed:  429.79 s
# Iteration:  129 Progress:  99.23  % Time Elapsed:  433.23 s
# Iteration:  130 Progress:  100.00  % Time Elapsed:  435.75 s
# Epoch 9 Finished.  Time per Epoch:  43.58 s
# Final Training Accuracy: 0.850479233226837
# Final Validation Accuracy: 0.8240740740740741
# Total time:   435.75 s  Time per Epoch:  43.58 s

# %% [markdown]
# The above example is only used to demonstrate the implementation of transfer learning. You are encouraged to explore different set of parameters and ways to improve the speed of the training. Note also that there is a larger dataset of flowers which you may want to try out as well to see if you can improve on the classification accuracy.

# %% [markdown]
# # Preventing Overfitting
#
# In the last few weeks we discussed the idea of **overfitting**,
# where a neural network model learns about the quirks of the training data,
# rather than information that is generalizable to the task
# at hand. We also briefly discussed idea of **underfitting**, but not in as much depth.
#
# The reason we did not discuss underfitting much is because nowadays,
# practitioners tend to avoid underfitting altogether by opting for more
# powerful models. Since computation is (relatively) cheap,
# and overfitting is much easier to detect, it is more straightforward
# to build a high-capacity model and use known techniques to prevent
# overfitting. So, always start with slightly more *capacity* than you need,
# then use some of the many strategies to prevent overfitting.
#
# We've actually already discussed several strategies for preventing overfitting:
#
# - Use a larger training set
# - Use a smaller network
# - Weight-sharing (as in convolutional neural networks)
# - Early stopping
# - Transfer Learning
#
# Some of these are more practical than others. For example, collecting a larger training
# set may be impractical or expensive in practice. Using a smaller network means that we need
# to restart training, rather than use what we already know about hyperparameters and appropriate
# weights.
#
# **Early stopping** was introduced in lab 2,
# where we did not use the trained weights from the last training iteration
# as our ``final'' model.
# Instead, we used a model (a set of weights) from a previous
# iteration of training. We chose the iteration/epoch to use based on
# the training curve.
#
# **Transfer learning** where we use pre-trained weights of a different model (e.g. AlexNet)
# as part of our neural network also helps prevent overfitting.
# The architectures and weights of AlexNet was trained using a larger
# dataset of over a million images, and was trained to solve a different image classification problem.
# Nevertheless, transfer learning allows us to leverage information
# from larger data sets with low computational cost. Effectively acting like a larger training set.
#
# These are only some of the techniques for preventing overfitting. We'll discuss more techniques today,
# including:
#
# - Data Normalization
# - Data Augmentation
# - Weight Decay
# - Model Averaging
# - Dropout
#
# We will use the MNIST digit recognition problem as a running example. Since we are studying overfitting,
# I will artificially reduce the number of training examples to 200.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# for reproducibility
torch.manual_seed(1)

mnist_data = datasets.MNIST('data', train=True, download=True, transform=transforms.ToTensor())
mnist_data = list(mnist_data)
mnist_train = mnist_data[:20]     #  20 train images
mnist_val   = mnist_data[100:5100] # 2000 validation images
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# Processing...
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.

# %% [markdown]
# We will also use the `MNISTClassifier` from the last few weeks as our base model:

# %%
class MNISTClassifier(nn.Module):
    def __init__(self):
        super(MNISTClassifier, self).__init__()
        self.layer1 = nn.Linear(28 * 28, 50)
        self.layer2 = nn.Linear(50, 20)
        self.layer3 = nn.Linear(20, 10)
    def forward(self, img):
        flattened = img.view(-1, 28 * 28)
        activation1 = F.relu(self.layer1(flattened))
        activation2 = F.relu(self.layer2(activation1))
        output = self.layer3(activation2)
        return output

# %% [markdown]
# And of course, our training code, with minor modifications that we will explain as we go along.

# %%
def train(model, train, valid, batch_size=20, num_iters=1, learn_rate=0.01, weight_decay=0):
    train_loader = torch.utils.data.DataLoader(train,
                                               batch_size=batch_size,
                                               shuffle=True) # shuffle after every epoch
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(model.parameters(), lr=learn_rate, momentum=0.9, weight_decay=weight_decay)

    iters, losses, train_acc, val_acc = [], [], [], []

    # training
    n = 0 # the number of iterations
    while True:
        if n >= num_iters:
            break
        for imgs, labels in iter(train_loader):
            model.train() #*****************************#
            out = model(imgs)             # forward pass
            loss = criterion(out, labels) # compute the total loss
            loss.backward()               # backward pass (compute parameter updates)
            optimizer.step()              # make the updates for each parameter
            optimizer.zero_grad()         # a clean up step for PyTorch

            # save the current training information
            if n % 10 == 9:
                iters.append(n)
                losses.append(float(loss)/batch_size)        # compute *average* loss
                train_acc.append(get_accuracy(model, train)) # compute training accuracy 
                val_acc.append(get_accuracy(model, valid))   # compute validation accuracy
            n += 1

    # plotting
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.title("Training Curve")
    plt.plot(iters, losses, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")

    plt.subplot(1,2,2)
    plt.title("Training Curve")
    plt.plot(iters, train_acc, label="Train")
    plt.plot(iters, val_acc, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Training Accuracy")
    plt.legend(loc='best')
    plt.show()

    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(val_acc[-1]))


train_acc_loader = torch.utils.data.DataLoader(mnist_train, batch_size=100)
val_acc_loader = torch.utils.data.DataLoader(mnist_val, batch_size=1000)

def get_accuracy(model, data):
    correct = 0
    total = 0
    model.eval() #*********#
    for imgs, labels in torch.utils.data.DataLoader(data, batch_size=64):
        output = model(imgs)
        pred = output.max(1, keepdim=True)[1] # get the index of the max logit
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]
    return correct / total

# %% [markdown]
# Without any intervention, our model gets to about 52-53% accuracy on the validation set.

# %%
model = MNISTClassifier()
train(model, mnist_train, mnist_val, num_iters=500)
# Out:
# Final Training Accuracy: 1.0
# Final Validation Accuracy: 0.5246

# %% [markdown]
# ## Data Normalization
#
# *Data normalization* means to scale the input features of a neural
# network, so that all features are scaled similarly (similar means
# and standard deviations). Although data normalization does not directly
# prevent overfitting, normalizing your data makes the training
# problem easier.
#
# Data normalization is less of an issues for input data -- like images --
# where all input features have similar interpretations.
# All features of an image are pixel intensities, all of which are scaled
# the same way. However, if we were performing prediction of, say,
# housing prices based on a house's number of bedroom, square footage, etc,
# we would want each of the features to be scaled similarly. A scale
# of mean 0 and standard deviation 1 is one approach. Another approach
# is to scale each feature so that they are in the range `[0, 1]`.
#
# The PyTorch transform `transforms.ToTensor()` automatically scales
# each pixel intensity to the range `[0, 1]`.
# In your lab 2 code, we used the following transform:

# %%
transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
# Out:
# Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))

# %% [markdown]
# This transform subtracts 0.5 from each pixel, and divides the
# result by 0.5. So, each pixel intensity will be in the range `[-1, 1]`.
# In general, having both positive and negative input values helps
# the network trains quickly (because of the way weights are initialized).
# Sticking with each pixel being in the range `[0, 1]` is usually fine.
#
# ## Data Augmentation
#
# While it is often expensive to gather more data, we can often
# programmatically *generate* more data points from our existing
# data set. We can make small alterations to our training set to obtain
# slightly different input data, but that is still valid.
# Common ways of obtaining new (image) data include:
#
# - Flipping each image horizontally or vertically (won't work for digit recognition, but might for other tasks)
# - Shifting each pixel a little to the left or right
# - Rotating the images a little
# - Adding noise to the image
#
# ... or even a combination of the above. For demonstration purposes, let's randomly
# rotate our digits a little to get new training samples.
#
# Here are the 20 images in our training set:

# %%
def show20(data):
    plt.figure(figsize=(10,2))
    for n, (img, label) in enumerate(data):
        if n >= 20:
            break
        plt.subplot(2, 10, n+1)
        plt.imshow(img)

mnist_imgs = datasets.MNIST('data', train=True, download=True)
show20(mnist_imgs)

# %% [markdown]
# Here are the 20 images in our training set, each rotated randomly, by up to 25 degrees.

# %%
mnist_new = datasets.MNIST('data', train=True, download=True, 
                           transform=transforms.RandomRotation(25))
show20(mnist_new)

# %% [markdown]
# If we apply the transformation again, we can get images with different rotations:

# %%
mnist_new = datasets.MNIST('data', train=True, download=True, transform=transforms.RandomRotation(25))
show20(mnist_new)

# %% [markdown]
# We can augment our data set by, say, randomly rotating each training data point 100 times:

# %%
augmented_train_data = []

my_transform = transforms.Compose([
    transforms.RandomRotation(25),
    transforms.ToTensor(),
])

for i in range(100):
    mnist_new = datasets.MNIST('data', train=True, download=True, transform=my_transform)
    for j, item in enumerate(mnist_new):
        if j >= 20:
            break
        augmented_train_data.append(item)

len(augmented_train_data)
# Out:
# 2000

# %% [markdown]
# We obtain a better validation accuracy after training on our expanded dataset.

# %%
model = MNISTClassifier()
train(model, augmented_train_data, mnist_val, num_iters=500)
# Out:
# Final Training Accuracy: 1.0
# Final Validation Accuracy: 0.6074

# %% [markdown]
# ## Weight Decay
#
# A more interesting technique that prevents overfitting is the idea of weight decay.
# The idea is to **penalize large weights**. We avoid large weights, because large weights
# mean that the prediction relies a lot on the content of one pixel, or on one unit. Intuitively,
# it does not make sense that the classification of an image should depend heavily on the
# content of one pixel, or even a few pixels.
#
# Mathematically, we penalize large weights by adding an extra term to the loss function,
# the term can look like the following:
#
# - $L^1$ regularization: $\sum_k |w_k|$
#     - Mathematically, this term encourages weights to be exactly 0
# - $L^2$ regularization: $\sum_k w_k^2$
#     - Mathematically, in each iteration the weight is pushed towards 0
# - Combination of $L^1$ and $L^2$ regularization: add a term $\sum_k |w_k| + w_k^2$  to the loss function.
#
# In PyTorch, weight decay can also be done automatically inside an optimizer. The parameter `weight_decay`
# of `optim.SGD` and most other optimizers uses $L^2$ regularization for weight decay. The value of the
# `weight_decay` parameter is another tunable hyperparameter.

# %%
model = MNISTClassifier()
train(model, mnist_train, mnist_val, num_iters=500, weight_decay=0.001)
# Out:
# Final Training Accuracy: 1.0
# Final Validation Accuracy: 0.5478

# %% [markdown]
# ## Dropout
#
# Yet another way to prevent overfitting is to build **many** models, then average
# their predictions at test time. Each model might have a different set of
# initial weights.
#
# We won't show an example of model averaging here. Instead, we will show another
# idea that sounds drastically different on the surface.
#
# This idea is called **dropout**: we will randomly "drop out", "zero out", or "remove" a portion
# of neurons from each training iteration.
#
# ![](imgs/dropout.png)
#
# In different iterations of training, we will drop out a different set of neurons.
#
# The technique has an effect of preventing weights from being overly dependent on
# each other: for example for one weight to be unnecessarily large to compensate for
# another unnecessarily large weight with the opposite sign. Weights are encouraged
# to be "more independent" of one another.
#
# During test time though, we will not drop out any neurons; instead we will use
# the entire set of weights. This means that our training time and test time behaviour
# of dropout layers are *different*. In the code for the function `train` and `get_accuracy`,
# we use `model.train()` and `model.eval()` to flag whether we want the model's training behaviour,
# or test time behaviour.
#
# While unintuitive, using all connections is a form
# of model averaging! We are effectively averaging over many different networks
# of various connectivity structures.

# %%
class MNISTClassifierWithDropout(nn.Module):
    def __init__(self):
        super(MNISTClassifierWithDropout, self).__init__()
        self.layer1 = nn.Linear(28 * 28, 50)
        self.layer2 = nn.Linear(50, 20)
        self.layer3 = nn.Linear(20, 10)
        self.dropout1 = nn.Dropout(0.4) # drop out layer with 20% dropped out neuron
        self.dropout2 = nn.Dropout(0.4)
        self.dropout3 = nn.Dropout(0.4)
    def forward(self, img):
        flattened = img.view(-1, 28 * 28)
        activation1 = F.relu(self.layer1(self.dropout1(flattened)))
        activation2 = F.relu(self.layer2(self.dropout2(activation1)))
        output = self.layer3(self.dropout3(activation2))
        return output

model = MNISTClassifierWithDropout()
train(model, mnist_train, mnist_val, num_iters=500)
# Out:
# Final Training Accuracy: 1.0
# Final Validation Accuracy: 0.5362
